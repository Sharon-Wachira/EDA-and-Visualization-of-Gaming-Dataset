# %% [markdown]
# # TASK 01

# %%
#import the selected library
import pandas as pd

# %%
# load the dataset
df=pd.read_csv(r'C:\Users\Gamers.csv')
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# # TASK 02

# %% [markdown]
# i)Number of unique video game genres in the dataset

# %%
# The number of unique game genres
unique_genres = df['Genre'].nunique()
print(f'Number of unique genres: {unique_genres}')
# Out:
# Number of unique genres: 12

# %% [markdown]
# ii) dimensions of the data

# %%
# the dimension of the data
df_dimension = df.shape
print(f'Dimension of the dataset: {df_dimension}')
# Out:
# Dimension of the dataset: (16598, 11)

# %% [markdown]
# iii) Total number of instances in the dataset

# %%
# total number of instances in the dataset
total_instances = len(df)
print(f'Total number of instances: {total_instances}')
# Out:
# Total number of instances: 16598

# %% [markdown]
# iv)Variable with most missing values and number of values

# %%
# the variable with the most missing values and the number of missing values 
# Missing values in each column 

missing_values = df.isnull().sum()

# Column with most missing values
variable_most_missing = missing_values.idxmax()
most_missing_count = missing_values.max()

print(f'Column with the most missing values: {variable_most_missing}')
print(f'Number of missing values: {most_missing_count}')
# Out:
# Column with the most missing values: Year
# Number of missing values: 271

# %% [markdown]
# v) Number of rows having wrong global sales

# %%
# Assess the number of rows having the wrong global sales
# Global sales are the sum of NA_Sales, EU_Sales, JP_Sales, and Other_Sales

# Create a mask for incorrect global sales
wrong_global_sales_rows = df[df['Global_Sales'] != df[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']].sum(axis=1)]

# Get the number of rows with wrong global sales
print(f"Number of rows with wrong global sales: {wrong_global_sales_rows.shape[0]}")
# Out:
# Number of rows with wrong global sales: 6772

# %% [markdown]
# vi) Retest

# %%
#Retest to validate rows with the wrong global sales


df[df['Global_Sales'] != df[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']].sum(axis=1)]
print(f"Retest of number of rows with wrong global sales: {wrong_global_sales_rows.shape[0]}")
# Out:
# Retest of number of rows with wrong global sales: 6772

# %% [markdown]
# vii) Top 3 publishers

# %%
 # the top 3 publishers for video game sales
top_publishers = df.groupby('Publisher')['Global_Sales'].sum().sort_values(ascending=False).head(3)
print('Top 3 publishers by video game sales:')
print(top_publishers)
# Out:
# Top 3 publishers by video game sales:
# Publisher
# Nintendo           1786.56
# Electronic Arts    1110.32
# Activision          727.46
# Name: Global_Sales, dtype: float64

# %% [markdown]
# viii) Genre with most video game

# %%
import matplotlib.pyplot as plt

genre_counts = df['Genre'].value_counts()

# Create a bar plot
plt.figure(figsize=(12, 6))
genre_counts.plot(kind='bar', color='maroon')

# titles and labels
plt.title('Number of Video Games by Genre')
plt.xlabel('Genre')
plt.ylabel('Number of Games')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.grid(axis='x')
# Show the plot
plt.show()

# %% [markdown]
# # TASK 3

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load the dataset
df=pd.read_csv(r'C:\Users\Gamers.csv')
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
# Set up plot aesthetics
sns.set(style="whitegrid")

# Bar plot to visualize which genre has the most games
plt.figure(figsize=(10, 6))
genre_count = df['Genre'].value_counts()
sns.barplot(x=genre_count.index, y=genre_count.values, color='red') 
plt.title('Number of Games per Genre', fontsize=16)
plt.xlabel('Genre', fontsize=14)
plt.ylabel('Number of Games', fontsize=14)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Count the number of games released per year
year_count = df['Year'].value_counts().sort_index()

# Find the year with the most games released
max_year = year_count.idxmax()
max_count = year_count.max()

# Plotting the data
plt.figure(figsize=(10, 6))
sns.lineplot(x=year_count.index, y=year_count.values, marker="o", color='brown')
plt.title('Number of Games Released per Year')
plt.xlabel('Year')
plt.ylabel('Number of Games')

# Annotate the year with the most games released
plt.annotate(f'Most Games: {max_year} ({max_count})', 
             xy=(max_year, max_count), 
             xytext=(max_year, max_count + 10), 
             arrowprops=dict(arrowstyle='->', color='black'),
             fontsize=10,
             color='black',
             ha='center')

plt.show()

# %%
# Group the data by Genre and sum the JP_Sales
jp_sales_by_genre = df.groupby('Genre')['JP_Sales'].sum().sort_values(ascending=False)

# Plotting the data
plt.figure(figsize=(10, 6))
sns.barplot(x=jp_sales_by_genre.index, y=jp_sales_by_genre.values, color='maroon')  
plt.title('Total Sales by Genre in Japan', fontsize=16)  
plt.xlabel('Genre', fontsize=12)  
plt.ylabel('Total Sales in Japan (in millions)', fontsize=12)  
plt.xticks(rotation=45)  
plt.show()

# %%
 #Count the number of games released each year
games_per_year = df['Year'].value_counts()

# Identify the year with the most games released
max_games_year = games_per_year.idxmax()
max_games_count = games_per_year.max()
print(f"The year with the most games released is {max_games_year} with a total of {max_games_count} games.")

# Identify the year with the least games released
min_games_year = games_per_year.idxmin()
min_games_count = games_per_year.min()
print(f"The year with the least games released is {min_games_year} with a total of {min_games_count} games.")
# Out:
# The year with the most games released is 2009.0 with a total of 1431 games.
# The year with the least games released is 2020.0 with a total of 1 games.

# %%
# Sales trend comparison between countries/continent and global sales
sales_comparison = df[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales']].sum()
print(f"Sales comparison by region:\n{sales_comparison}")
# Out:
# Sales comparison by region:
# NA_Sales        4392.95
# EU_Sales        2434.13
# JP_Sales        1291.02
# Other_Sales      797.75
# Global_Sales    8920.44
# dtype: float64

# %% [markdown]
# # TASK 4

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Improved Plot: Horizontal bar plot with data labels for clarity
plt.figure(figsize=(10, 6))
jp_sales_by_genre = df.groupby('Genre')['JP_Sales'].sum().sort_values(ascending=False)
bars = plt.barh(jp_sales_by_genre.index, jp_sales_by_genre.values, color='brown')
# Add data labels to the bars
for bar in bars:
    plt.text(bar.get_width(), bar.get_y() + bar.get_height()/2, f'{bar.get_width():.2f}', va='center')
plt.title('Total Sales in Japan by Genre (Improved)', fontsize=14)
plt.xlabel('Total Sales (in millions)', fontsize=12)
plt.ylabel('Genre', fontsize=12)
plt.gca().invert_yaxis()  # Invert y-axis to keep the highest sales at the top
plt.show()

# %% [markdown]
# # TASK 5

# %% [markdown]
# i)Best- selling video game in North America

# %%
import matplotlib.pyplot as plt
import seaborn as sns

top_na_sales = df[['Name', 'NA_Sales']].sort_values(by='NA_Sales', ascending=False).head(10)

# Plotting the data
plt.figure(figsize=(12, 6))
sns.barplot(x='NA_Sales', y='Name', data=top_na_sales, color='maroon')  # Set bar color to maroon

plt.title('Top 10 Best-Selling Video Games in North America', fontsize=16)
plt.xlabel('Sales in North America (in millions)', fontsize=14)
plt.ylabel('Video Game Title', fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
#  ii)	Country which exhibits a consistent sales trend for the past thirty-two years since 1985.

# %%
# Preparing the data for sales trend since 1985
df_filtered = df[df['Year'] >= 1985]  

# Grouping sales by year and country/region
sales_by_year = df_filtered.groupby('Year')[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']].sum()

plt.figure(figsize=(10, 6))
for region in ['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']:
    plt.plot(sales_by_year.index, sales_by_year[region], label=region)

plt.title('Consistent Sales Trend by Region (1985 - Present)', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Total Sales (in millions)', fontsize=12)
plt.legend(title='Region')
plt.grid(True)
plt.show()

# Calculate standard deviation of sales for each region (lower = more consistent)
sales_std_dev = sales_by_year.std()
print(sales_std_dev)

# Region with the most consistent sales trend
most_consistent_region = sales_std_dev.idxmin()
print(f"The region with the most consistent sales trend is: {most_consistent_region}")
# Out:
# NA_Sales       109.571141
# EU_Sales        63.611140
# JP_Sales        19.310774
# Other_Sales     25.583533
# dtype: float64
# The region with the most consistent sales trend is: JP_Sales

# %% [markdown]
# iii) Correlation

# %%
# Group by publisher, count the number of games, and sum the total global sales
publisher_sales = df.groupby('Publisher').agg({'Name': 'count', 'Global_Sales': 'sum'}).reset_index()
publisher_sales.columns = ['Publisher', 'Games_Published', 'Total_Sales']

# Select top publishers by total global sales
top_publishers = publisher_sales.sort_values(by='Total_Sales', ascending=False).head(10)

# Scatter plot with regression line
plt.figure(figsize=(10, 6))
sns.regplot(x='Games_Published', y='Total_Sales', data=top_publishers, scatter_kws={'color': 'green'}, line_kws={'color': 'red'})
plt.title('Correlation Between Number of Games Published and Global Sales by Top Publishers', fontsize=16)
plt.xlabel('Number of Games Published', fontsize=14)
plt.ylabel('Total Global Sales (millions)', fontsize=14)
plt.tight_layout()
plt.show()

# Perform linear regression to find the slope of the line
x = top_publishers['Games_Published']
y = top_publishers['Total_Sales']
slope, intercept = np.polyfit(x, y, 1)

# Print summarized inference
if slope > 0:
    print(f"Correlation between the number of games published and global sales is positive,slope of {slope:.2f}. This indicates that publishers who release more games tend to have higher total global sales.")
elif slope < 0:
    print(f"Negative correlation between the number of games published and global sales,slope of {slope:.2f}.more games does not necessarily lead to higher sales.")
else:
    print("No clear correlation between the number of games published and global sales.")
# Out:
# Correlation between the number of games published and global sales is positive,slope of 0.46. This indicates that publishers who release more games tend to have higher total global sales.

# %%
print("\n--- End of Analysis ---")
# Out:
# --- End of Analysis ---
